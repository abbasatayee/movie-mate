# %%
import pandas as pd
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from pathlib import Path

# %%
current_dir = Path.cwd()
insert_dir = os.path.join(current_dir , '..' , 'models-architecture');
sys.path.insert(0 ,insert_dir)

# %%
from ncf import NeuralCollaborativeFramework

# %%
rname = ['user_id' , 'movie_id', 'rating','timestamp']
ratings_df = pd.read_csv('../../data/mv-lens-1m/ratings.dat', delimiter = '::',header=None, engine='python' , names=rname)

ratings_df.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
num_users = ratings_df['user_id'].nunique()
num_movies = ratings_df['movie_id'].nunique()

print(num_users , num_movies)
# Out:
# 6040 3706

# %%
model = NeuralCollaborativeFramework(num_users , num_movies ,dropout_rate=0.1)
print(f"ncf model architecture {model}")
# Out:
# ncf model architecture NeuralCollaborativeFramework(
#   (user_embedding): Embedding(6040, 32)
#   (movie_embedding): Embedding(3706, 32)
#   (MLP): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=16, out_features=8, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=8, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
from torch.utils.data import Dataset, DataLoader

# Prepare data tensors (convert user and movie ids to zero-based indices)
user_ids = torch.tensor(ratings_df['user_id'].values - 1, dtype=torch.long)
movie_ids = torch.tensor(ratings_df['movie_id'].values - 1, dtype=torch.long)


ratings = torch.tensor(ratings_df['rating'].values.astype(np.float32), dtype=torch.float32)

num_samples = len(ratings)
indices = torch.randperm(num_samples)
split = int(0.8 * num_samples)

train_indices = indices[:split]
val_indices = indices[split:]


class RatingsDataset(Dataset):
    def __init__(self, user_ids, movie_ids, ratings, indices):
        self.user_ids = user_ids[indices]
        self.movie_ids = movie_ids[indices]
        self.ratings = ratings[indices]

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return (
            self.user_ids[idx],
            self.movie_ids[idx],
            self.ratings[idx],
        )

train_dataset = RatingsDataset(user_ids, movie_ids, ratings, train_indices)
val_dataset = RatingsDataset(user_ids, movie_ids, ratings, val_indices)
batch_size = 1024

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


movie_batch, user_batch, rating_batch = next(iter(train_loader))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 , )

num_epochs = 40

history = {"train_rmse": [], "val_rmse": []}

for epoch in range(1, num_epochs + 1):
    model.train()
    train_squared_loss = 0.0

    for batch_user, batch_movie, batch_rating in train_loader:
        batch_user = batch_user.to(device)
        batch_movie = batch_movie.to(device)
        batch_rating = batch_rating.to(device)

        optimizer.zero_grad()
        outputs = model(batch_user, batch_movie).squeeze()
        loss = criterion(outputs, batch_rating)
        loss.backward()
        optimizer.step()

        train_squared_loss += loss.item() * batch_rating.size(0)

    train_mse = train_squared_loss / len(train_loader.dataset)
    train_rmse = train_mse ** 0.5

    model.eval()
    val_squared_loss = 0.0

    with torch.no_grad():
        for batch_user, batch_movie, batch_rating in val_loader:
            batch_user = batch_user.to(device)
            batch_movie = batch_movie.to(device)
            batch_rating = batch_rating.to(device)

            outputs = model(batch_user, batch_movie).squeeze()
            loss = criterion(outputs, batch_rating)

            val_squared_loss += loss.item() * batch_rating.size(0)

    val_mse = val_squared_loss / len(val_loader.dataset)
    val_rmse = val_mse ** 0.5

    history["train_rmse"].append(train_rmse)
    history["val_rmse"].append(val_rmse)

    print(f"Epoch {epoch}/{num_epochs} - Train RMSE: {train_rmse:.4f} - Val RMSE: {val_rmse:.4f}")
# Out:
# Epoch 1/40 - Train RMSE: 0.9516 - Val RMSE: 0.9084
# Epoch 2/40 - Train RMSE: 0.9101 - Val RMSE: 0.9007
# Epoch 3/40 - Train RMSE: 0.8994 - Val RMSE: 0.8940
# Epoch 4/40 - Train RMSE: 0.8900 - Val RMSE: 0.8885
# Epoch 5/40 - Train RMSE: 0.8823 - Val RMSE: 0.8858
# Epoch 6/40 - Train RMSE: 0.8773 - Val RMSE: 0.8858
# Epoch 7/40 - Train RMSE: 0.8726 - Val RMSE: 0.8863
# Epoch 8/40 - Train RMSE: 0.8690 - Val RMSE: 0.8845
# Epoch 9/40 - Train RMSE: 0.8655 - Val RMSE: 0.8852
# Epoch 10/40 - Train RMSE: 0.8619 - Val RMSE: 0.8846
# Epoch 11/40 - Train RMSE: 0.8583 - Val RMSE: 0.8859
# Epoch 12/40 - Train RMSE: 0.8557 - Val RMSE: 0.8833
# Epoch 13/40 - Train RMSE: 0.8524 - Val RMSE: 0.8841
# Epoch 14/40 - Train RMSE: 0.8496 - Val RMSE: 0.8828
# Epoch 15/40 - Train RMSE: 0.8471 - Val RMSE: 0.8828
# Epoch 16/40 - Train RMSE: 0.8445 - Val RMSE: 0.8827
# Epoch 17/40 - Train RMSE: 0.8419 - Val RMSE: 0.8828
# Epoch 18/40 - Train RMSE: 0.8399 - Val RMSE: 0.8824
# Epoch 19/40 - Train RMSE: 0.8378 - Val RMSE: 0.8822
# Epoch 20/40 - Train RMSE: 0.8361 - Val RMSE: 0.8809
# Epoch 21/40 - Train RMSE: 0.8343 - Val RMSE: 0.8807
# Epoch 22/40 - Train RMSE: 0.8324 - Val RMSE: 0.8811
# Epoch 23/40 - Train RMSE: 0.8305 - Val RMSE: 0.8813
# Epoch 24/40 - Train RMSE: 0.8293 - Val RMSE: 0.8820
# Epoch 25/40 - Train RMSE: 0.8281 - Val RMSE: 0.8808
# Epoch 26/40 - Train RMSE: 0.8265 - Val RMSE: 0.8808
# Epoch 27/40 - Train RMSE: 0.8256 - Val RMSE: 0.8809
# Epoch 28/40 - Train RMSE: 0.8241 - Val RMSE: 0.8818
# Epoch 29/40 - Train RMSE: 0.8228 - Val RMSE: 0.8809
# Epoch 30/40 - Train RMSE: 0.8219 - Val RMSE: 0.8818
# Epoch 31/40 - Train RMSE: 0.8210 - Val RMSE: 0.8811
# Epoch 32/40 - Train RMSE: 0.8200 - Val RMSE: 0.8817
# Epoch 33/40 - Train RMSE: 0.8186 - Val RMSE: 0.8822
# Epoch 34/40 - Train RMSE: 0.8186 - Val RMSE: 0.8813
# Epoch 35/40 - Train RMSE: 0.8174 - Val RMSE: 0.8819
# Epoch 36/40 - Train RMSE: 0.8161 - Val RMSE: 0.8834
# Epoch 37/40 - Train RMSE: 0.8166 - Val RMSE: 0.8821
# Epoch 38/40 - Train RMSE: 0.8155 - Val RMSE: 0.8824
# Epoch 39/40 - Train RMSE: 0.8144 - Val RMSE: 0.8816
# Epoch 40/40 - Train RMSE: 0.8139 - Val RMSE: 0.8831

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_rmse"], label="Train RMSE")
plt.plot(epochs, history["val_rmse"], label="Validation RMSE")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.title("Training vs Validation RMSE over 10 epochs")
plt.legend()
plt.grid(True)
plt.show()

print("Final Train RMSE:", history["train_rmse"][-1])
print("Final Val RMSE:", history["val_rmse"][-1])
# Out:
# Final Train RMSE: 0.813945036961495
# Final Val RMSE: 0.883110915620394

# %% [markdown]
# # Overfitted

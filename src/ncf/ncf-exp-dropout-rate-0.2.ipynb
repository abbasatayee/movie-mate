# %%
import pandas as pd
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from pathlib import Path

# %%
current_dir = Path.cwd()
insert_dir = os.path.join(current_dir , '..' , 'models-architecture');
sys.path.insert(0 ,insert_dir)

# %%
from ncf import NeuralCollaborativeFramework

# %%
rname = ['user_id' , 'movie_id', 'rating','timestamp']
ratings_df = pd.read_csv('../../data/mv-lens-1m/ratings.dat', delimiter = '::',header=None, engine='python' , names=rname)

ratings_df.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
num_users = ratings_df['user_id'].nunique()
num_movies = ratings_df['movie_id'].nunique()

print(num_users , num_movies)
# Out:
# 6040 3706

# %%
model = NeuralCollaborativeFramework(num_users , num_movies ,dropout_rate=0.2)
print(f"ncf model architecture {model}")
# Out:
# ncf model architecture NeuralCollaborativeFramework(
#   (user_embedding): Embedding(6040, 32)
#   (movie_embedding): Embedding(3706, 32)
#   (MLP): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=8, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Linear(in_features=8, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
from torch.utils.data import Dataset, DataLoader

# Prepare data tensors (convert user and movie ids to zero-based indices)
user_ids = torch.tensor(ratings_df['user_id'].values - 1, dtype=torch.long)
movie_ids = torch.tensor(ratings_df['movie_id'].values - 1, dtype=torch.long)


ratings = torch.tensor(ratings_df['rating'].values.astype(np.float32), dtype=torch.float32)

num_samples = len(ratings)
indices = torch.randperm(num_samples)
split = int(0.8 * num_samples)

train_indices = indices[:split]
val_indices = indices[split:]


class RatingsDataset(Dataset):
    def __init__(self, user_ids, movie_ids, ratings, indices):
        self.user_ids = user_ids[indices]
        self.movie_ids = movie_ids[indices]
        self.ratings = ratings[indices]

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return (
            self.user_ids[idx],
            self.movie_ids[idx],
            self.ratings[idx],
        )

train_dataset = RatingsDataset(user_ids, movie_ids, ratings, train_indices)
val_dataset = RatingsDataset(user_ids, movie_ids, ratings, val_indices)
batch_size = 1024

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


movie_batch, user_batch, rating_batch = next(iter(train_loader))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3 , )

num_epochs = 40

history = {"train_rmse": [], "val_rmse": []}

for epoch in range(1, num_epochs + 1):
    model.train()
    train_squared_loss = 0.0

    for batch_user, batch_movie, batch_rating in train_loader:
        batch_user = batch_user.to(device)
        batch_movie = batch_movie.to(device)
        batch_rating = batch_rating.to(device)

        optimizer.zero_grad()
        outputs = model(batch_user, batch_movie).squeeze()
        loss = criterion(outputs, batch_rating)
        loss.backward()
        optimizer.step()

        train_squared_loss += loss.item() * batch_rating.size(0)

    train_mse = train_squared_loss / len(train_loader.dataset)
    train_rmse = train_mse ** 0.5

    model.eval()
    val_squared_loss = 0.0

    with torch.no_grad():
        for batch_user, batch_movie, batch_rating in val_loader:
            batch_user = batch_user.to(device)
            batch_movie = batch_movie.to(device)
            batch_rating = batch_rating.to(device)

            outputs = model(batch_user, batch_movie).squeeze()
            loss = criterion(outputs, batch_rating)

            val_squared_loss += loss.item() * batch_rating.size(0)

    val_mse = val_squared_loss / len(val_loader.dataset)
    val_rmse = val_mse ** 0.5

    history["train_rmse"].append(train_rmse)
    history["val_rmse"].append(val_rmse)

    print(f"Epoch {epoch}/{num_epochs} - Train RMSE: {train_rmse:.4f} - Val RMSE: {val_rmse:.4f}")
# Out:
# Epoch 1/40 - Train RMSE: 0.9716 - Val RMSE: 0.9145
# Epoch 2/40 - Train RMSE: 0.9246 - Val RMSE: 0.9079
# Epoch 3/40 - Train RMSE: 0.9167 - Val RMSE: 0.9048
# Epoch 4/40 - Train RMSE: 0.9119 - Val RMSE: 0.9014
# Epoch 5/40 - Train RMSE: 0.9063 - Val RMSE: 0.8963
# Epoch 6/40 - Train RMSE: 0.9013 - Val RMSE: 0.8943
# Epoch 7/40 - Train RMSE: 0.8971 - Val RMSE: 0.8920
# Epoch 8/40 - Train RMSE: 0.8935 - Val RMSE: 0.8908
# Epoch 9/40 - Train RMSE: 0.8902 - Val RMSE: 0.8905
# Epoch 10/40 - Train RMSE: 0.8880 - Val RMSE: 0.8898
# Epoch 11/40 - Train RMSE: 0.8857 - Val RMSE: 0.8889
# Epoch 12/40 - Train RMSE: 0.8846 - Val RMSE: 0.8888
# Epoch 13/40 - Train RMSE: 0.8828 - Val RMSE: 0.8904
# Epoch 14/40 - Train RMSE: 0.8820 - Val RMSE: 0.8884
# Epoch 15/40 - Train RMSE: 0.8807 - Val RMSE: 0.8886
# Epoch 16/40 - Train RMSE: 0.8791 - Val RMSE: 0.8889
# Epoch 17/40 - Train RMSE: 0.8783 - Val RMSE: 0.8893
# Epoch 18/40 - Train RMSE: 0.8774 - Val RMSE: 0.8884
# Epoch 19/40 - Train RMSE: 0.8764 - Val RMSE: 0.8884
# Epoch 20/40 - Train RMSE: 0.8754 - Val RMSE: 0.8885
# Epoch 21/40 - Train RMSE: 0.8746 - Val RMSE: 0.8889
# Epoch 22/40 - Train RMSE: 0.8739 - Val RMSE: 0.8887
# Epoch 23/40 - Train RMSE: 0.8732 - Val RMSE: 0.8894
# Epoch 24/40 - Train RMSE: 0.8724 - Val RMSE: 0.8892
# Epoch 25/40 - Train RMSE: 0.8716 - Val RMSE: 0.8878
# Epoch 26/40 - Train RMSE: 0.8718 - Val RMSE: 0.8888
# Epoch 27/40 - Train RMSE: 0.8704 - Val RMSE: 0.8891
# Epoch 28/40 - Train RMSE: 0.8700 - Val RMSE: 0.8879
# Epoch 29/40 - Train RMSE: 0.8694 - Val RMSE: 0.8877
# Epoch 30/40 - Train RMSE: 0.8687 - Val RMSE: 0.8881
# Epoch 31/40 - Train RMSE: 0.8680 - Val RMSE: 0.8874
# Epoch 32/40 - Train RMSE: 0.8675 - Val RMSE: 0.8880
# Epoch 33/40 - Train RMSE: 0.8672 - Val RMSE: 0.8878
# Epoch 34/40 - Train RMSE: 0.8668 - Val RMSE: 0.8875
# Epoch 35/40 - Train RMSE: 0.8661 - Val RMSE: 0.8871
# Epoch 36/40 - Train RMSE: 0.8654 - Val RMSE: 0.8876
# Epoch 37/40 - Train RMSE: 0.8649 - Val RMSE: 0.8870
# Epoch 38/40 - Train RMSE: 0.8643 - Val RMSE: 0.8873
# Epoch 39/40 - Train RMSE: 0.8644 - Val RMSE: 0.8873
# Epoch 40/40 - Train RMSE: 0.8640 - Val RMSE: 0.8862

# %%
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_rmse"], label="Train RMSE")
plt.plot(epochs, history["val_rmse"], label="Validation RMSE")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.title("Training vs Validation RMSE over 10 epochs")
plt.legend()
plt.grid(True)
plt.show()

print("Final Train RMSE:", history["train_rmse"][-1])
print("Final Val RMSE:", history["val_rmse"][-1])
# Out:
# Final Train RMSE: 0.8639933155992053
# Final Val RMSE: 0.8861730117331083

# %% [markdown]
# # Overfitted
